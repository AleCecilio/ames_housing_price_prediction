# %% [markdown]
# ## Análise Exploratória de Dados
#
# Neste arquivo está a etapa responsável por compreender a estrutura do dataset antes da construção do modelo. Nele são feitas verificações como estatísticas descritivas, identificação de valores ausentes, análise de correlação e busca por possíveis outliers.
#
# Optou-se por utilizar apenas um arquivo de EDA porque o escopo do projeto é simples, permitindo concentrar todas as análises exploratórias em um único local, o que facilita a organização e o entendimento do processo.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/raw/Ames_Housing_Data.csv ')

# %%
df

# %% [markdown]
# ### Identificação de Outliers com Base na Correlação com o Rótulo
#
# Nesta etapa buscamos identificar possíveis **outliers** analisando a relação entre as *features* e o **rótulo (SalePrice)**. Para isso, observamos as variáveis com maior correlação com o preço das casas e analisamos visualmente esses relacionamentos para encontrar valores que fogem do padrão esperado e que podem prejudicar o treinamento do modelo.

# %%
df.select_dtypes(include='number').corr()['SalePrice'].sort_values(ascending=False)

# %%
sns.scatterplot(x='Overall Qual', y='SalePrice', data=df)

# %%
sns.scatterplot(x='Gr Liv Area', y='SalePrice', data=df)

# %%
df[(df['Overall Qual']>8) & (df['SalePrice']<200000)]

# %%
df[(df['Gr Liv Area']>4000) & (df['SalePrice']<400000)]

# %%
df = pd.read_csv('../data/processed/Ames_outliers_removed.csv')

# %%
sns.scatterplot(x='Gr Liv Area', y='SalePrice', data=df)

# %% [markdown]
# ### Descrição das Features
#
# Nesta etapa utilizaremos o arquivo **Ames_Housing_Feature_Description.txt** para entender melhor o significado de cada *feature* presente no dataset e o que seus respectivos valores representam. Isso ajuda a interpretar corretamente as variáveis durante a análise e nas etapas de preparação dos dados.

# %%
with open('../data/raw/Ames_Housing_Feature_Description.txt', 'r') as f:
    print(f.read())

# %% [markdown]
# ### Análise de Dados Ausentes
#
# A partir desta etapa exploraremos os **dados ausentes** presentes no dataset. O objetivo é identificar quais *features* possuem valores faltantes, a quantidade de ocorrências e avaliar possíveis estratégias de tratamento para cada caso.

# %%
df.info()

# %%
df.head()

# %%
def percent_missing(df):
    percent_nan = 100 * df.isnull().sum() / len(df)
    percent_nan = percent_nan[percent_nan > 0].sort_values()

    return percent_nan

# %%
percent_nan = percent_missing(df)

# %%
percent_nan

# %%
plt.figure(figsize=(8,4), dpi=200)

sns.barplot(
    x=percent_nan.index,
    y=percent_nan,
    hue=percent_nan.index,
    palette='viridis',
    legend=False
)

plt.xticks(rotation=90)
plt.title('Percent Missing Values by Column')
plt.xlabel('Features')
plt.ylabel('Percent Missing')

# %%
plt.figure(figsize=(8,4), dpi=200)

sns.barplot(
    x=percent_nan.index,
    y=percent_nan,
    hue=percent_nan.index,
    palette='viridis',
    legend=False
)

plt.xticks(rotation=90)
plt.ylim(0, 1)

# %%
percent_nan [percent_nan < 1]

# %%
100/len(df)

# %%
df[df['Electrical'].isnull()]

# %%
df[df['Electrical'].isnull()]['Garage Area']

# %%
df[df['Bsmt Half Bath'].isnull()]

# %%
df = df.dropna(axis=0,subset=['Electrical', 'Garage Cars'])

# %%
percent_nan = percent_missing(df)

# %%
percent_nan[percent_nan<1]

# %%
plt.figure(figsize=(8,4), dpi=200)

sns.barplot(
    x=percent_nan.index,
    y=percent_nan,
    hue=percent_nan.index,
    palette='viridis',
    legend=False
)

plt.xticks(rotation=90)
plt.ylim(0, 1)

# %%
df[df['Bsmt Half Bath'].isnull()]

# %%
df[df['Bsmt Full Bath'].isnull()]

# %%
df[df['Bsmt Unf SF'].isnull()]

# %%
# BSMT COLUNAS NUMERICAS --> fillna 0
bsmt_num_cols = [
    'Bsmt Full Bath',
    'Bsmt Half Bath',
    'Bsmt Unf SF',
    'BsmtFin SF 1',
    'BsmtFin SF 2',
    'Total Bsmt SF'
]

df[bsmt_num_cols] = df[bsmt_num_cols].fillna(0)

# BSMT COLUNAS STRING --> fillna 'None'
bsmt_str_cols =  [
    'Bsmt Qual',
    'Bsmt Cond',
    'Bsmt Exposure',
    'BsmtFin Type 1',
    'BsmtFin Type 2'
]

df[bsmt_str_cols] = df[bsmt_str_cols].fillna('None')

# %%
df[df['Bsmt Full Bath'].isnull()]

# %%
percent_nan = percent_missing(df)

plt.figure(figsize=(8,4), dpi=200)

sns.barplot(
    x=percent_nan.index,
    y=percent_nan,
    hue=percent_nan.index,
    palette='viridis',
    legend=False
)

plt.xticks(rotation=90)
plt.ylim(0, 1)

# %%
df['Mas Vnr Type'] = df['Mas Vnr Type'].fillna('None')
df['Mas Vnr Area'] = df['Mas Vnr Area'].fillna(0)

# %%
percent_nan = percent_missing(df)

plt.figure(figsize=(8,4), dpi=200)

sns.barplot(
    x=percent_nan.index,
    y=percent_nan,
    hue=percent_nan.index,
    palette='viridis',
    legend=False
)

plt.xticks(rotation=90)
plt.ylim(0, 1)

# %%
percent_nan [percent_nan < 1]

# %%
plt.figure(figsize=(8,4), dpi=200)

sns.barplot(
    x=percent_nan.index,
    y=percent_nan,
    hue=percent_nan.index,
    palette='viridis',
    legend=False
)

plt.xticks(rotation=90)
plt.title('Percent Missing Values by Column')
plt.xlabel('Features')
plt.ylabel('Percent Missing')

# %%
garage_str_cols = ['Garage Type', 'Garage Qual', 'Garage Finish', 'Garage Cond']

# %%
df[garage_str_cols] = df[garage_str_cols].fillna('None')

# %%
percent_nan = percent_missing(df)

# %%
plt.figure(figsize=(8,4), dpi=200)

sns.barplot(
    x=percent_nan.index,
    y=percent_nan,
    hue=percent_nan.index,
    palette='viridis',
    legend=False
)

plt.xticks(rotation=90)
plt.title('Percent Missing Values by Column')
plt.xlabel('Features')
plt.ylabel('Percent Missing')

# %%
df['Garage Yr Blt'] = df['Garage Yr Blt'].fillna(0)

# %%
percent_nan = percent_missing(df)

# %%
plt.figure(figsize=(8,4), dpi=200)

sns.barplot(
    x=percent_nan.index,
    y=percent_nan,
    hue=percent_nan.index,
    palette='viridis',
    legend=False
)

plt.xticks(rotation=90)
plt.title('Percent Missing Values by Column')
plt.xlabel('Features')
plt.ylabel('Percent Missing')

# %%
df = df.drop(columns=['Pool QC', 'Misc Feature', 'Alley', 'Fence'])

# %%
percent_nan = percent_missing(df)

# %%
plt.figure(figsize=(8,4))

sns.barplot(
    x=percent_nan.index,
    y=percent_nan,
    hue=percent_nan.index,
    palette='viridis',
    legend=False
)

plt.xticks(rotation=90)
plt.title('Percent Missing Values by Column')
plt.xlabel('Features')
plt.ylabel('Percent Missing')

# %%
df['Fireplace Qu'].value_counts()

# %%
df['Fireplace Qu'] = df['Fireplace Qu'].fillna('None')

# %%
df['Lot Frontage'].value_counts()

# %%
plt.figure(figsize=(8,12), dpi=200)
sns.boxplot(x='Lot Frontage', y='Neighborhood', data=df, orient='h')

# %%
df.groupby('Neighborhood')['Lot Frontage'].median()

# %%
grouped = df.groupby('Neighborhood')['Lot Frontage']
df['Lot Frontage'] = grouped.transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()

# %%
df['Lot Frontage'] = df['Lot Frontage'].fillna(0)

# %%
df.isnull().sum()
